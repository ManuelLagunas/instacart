# %% [markdown]
# # EDA Products

# %% [markdown]
# ———- libreries ———

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %% [markdown]
# ———- read data ———-

# %%
df = pd.read_csv('datasets/products.csv', sep=';')

# %% [markdown]
# ———- eda ———-

# %%
ProfileReport(df)
# Out:
# <script type="application/vnd.jupyter.widget-view+json">
# {"model_id":"0e0bcd02d45242a4bbabb2b7acb63223","version_major":2,"version_minor":0,"quarto_mimetype":"application/vnd.jupyter.widget-view+json"}
# </script>
# <script type="application/vnd.jupyter.widget-view+json">
# {"model_id":"5d5177f887414fa2b7012485039ae7de","version_major":2,"version_minor":0,"quarto_mimetype":"application/vnd.jupyter.widget-view+json"}
# </script>
# <script type="application/vnd.jupyter.widget-view+json">
# {"model_id":"58e505302e524b5998917f70e018a4f9","version_major":2,"version_minor":0,"quarto_mimetype":"application/vnd.jupyter.widget-view+json"}
# </script>
# ...
