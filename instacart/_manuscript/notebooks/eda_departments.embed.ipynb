# %% [markdown]
# # EDA Departments

# %% [markdown]
# ———- libreries ———

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %% [markdown]
# ———- read data ———-

# %%
df = pd.read_csv('datasets/departments_raw.csv', sep=';')

# %% [markdown]
# ———- eda ———-

# %%
ProfileReport(df)
# Out:
# <script type="application/vnd.jupyter.widget-view+json">
# {"model_id":"5b52b80eec3c41b3b5a7df4fadbaf085","version_major":2,"version_minor":0,"quarto_mimetype":"application/vnd.jupyter.widget-view+json"}
# </script>
# <script type="application/vnd.jupyter.widget-view+json">
# {"model_id":"688cab75ea3a4181a210f223652211bf","version_major":2,"version_minor":0,"quarto_mimetype":"application/vnd.jupyter.widget-view+json"}
# </script>
# <script type="application/vnd.jupyter.widget-view+json">
# {"model_id":"f83d9a8529074570898720cdde9e3416","version_major":2,"version_minor":0,"quarto_mimetype":"application/vnd.jupyter.widget-view+json"}
# </script>
# ...
